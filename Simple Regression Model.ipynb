# %%
#run the following commands in the CMD prompt...
#install scikit-learn
#install cufflinks
#install plotly
#install cufflinks plotly


import pandas as pd
import numpy as np
import scipy as sp

#import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import math 

#import plotly.plotly as py
#import plotly.plotly as py
#import plotly.figure_factory as ff
#import pandas as pd



from random import randint
TRAIN_SET_LIMIT = 1000
TRAIN_SET_COUNT = 100

TRAIN_INPUT = list()
TRAIN_OUTPUT = list()
for i in range(TRAIN_SET_COUNT):
    a = randint(0, TRAIN_SET_LIMIT)
    b = randint(0, TRAIN_SET_LIMIT)
    c = randint(0, TRAIN_SET_LIMIT)
    op = a + (2*b) + (3*c)
    TRAIN_INPUT.append([a, b, c])
    TRAIN_OUTPUT.append(op)

# %%
from sklearn.linear_model import LinearRegression

predictor = LinearRegression(n_jobs=-1)
predictor.fit(X=TRAIN_INPUT, y=TRAIN_OUTPUT)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False)

# %%
X_TEST = [[10, 20, 30]]

outcome = predictor.predict(X=X_TEST)

coefficients = predictor.coef_


#Print Values 
print(TRAIN_INPUT)


#Display Plot 
from IPython.display import display, HTML
# %matplotlib notebook 
x = TRAIN_INPUT
y = TRAIN_OUTPUT 
fig = plt.figure()
plt.plot(x,y)
#ax=fig.add_axes()
#ax.plot(x,y)
#ax.set_title("hi")
#ax.set_xlabel('x')
#ax.set_ylabel('y')


print('Outcome : {}\nCoefficients : {}'.format(outcome, coefficients))
# Out:
# [[223, 535, 678], [975, 699, 541], [270, 8, 255], [791, 508, 461], [219, 34, 727], [503, 274, 301], [128, 441, 632], [819, 69, 491], [376, 299, 474], [190, 648, 705], [598, 938, 245], [358, 797, 399], [728, 789, 513], [56, 715, 570], [722, 379, 940], [553, 947, 707], [268, 828, 318], [965, 818, 96], [859, 401, 190], [508, 164, 993], [99, 76, 198], [84, 179, 408], [812, 944, 310], [386, 877, 182], [692, 593, 401], [526, 458, 387], [868, 919, 978], [24, 984, 309], [842, 463, 42], [389, 557, 457], [869, 925, 279], [860, 171, 172], [394, 134, 792], [806, 815, 610], [330, 284, 795], [314, 769, 64], [605, 394, 389], [476, 74, 810], [188, 493, 715], [820, 217, 970], [26, 135, 391], [781, 946, 620], [295, 371, 87], [485, 303, 890], [415, 505, 528], [630, 182, 385], [414, 69, 41], [81, 1000, 336], [614, 184, 325], [862, 874, 371], [815, 138, 489], [921, 998, 810], [404, 599, 804], [385, 58, 307], [492, 310, 273], [658, 718, 887], [332, 504, 276], [249, 346, 541], [598, 83, 885], [246, 76, 475], [131, 202, 863], [20, 892, 266], [608, 105, 359], [245, 257, 609], [916, 586, 368], [813, 86, 980], [390, 330, 994], [315, 630, 502], [208, 609, 378], [922, 475, 80], [756, 228, 918], [16, 397, 40], [734, 932, 990], [266, 196, 37], [583, 111, 842], [84, 129, 585], [608, 844, 217], [608, 334, 579], [866, 150, 395], [751, 959, 435], [107, 996, 420], [515, 651, 79], [849, 703, 486], [295, 839, 526], [583, 313, 654], [746, 518, 631], [951, 790, 70], [105, 543, 966], [746, 329, 588], [55, 706, 148], [202, 857, 390], [947, 876, 451], [365, 54, 931], [679, 786, 94], [903, 106, 953], [530, 477, 185], [831, 19, 972], [189, 951, 318], [618, 940, 277], [647, 286, 720]]
# <img src="data:image/png;base64,..." width="640">
# Outcome : [140.]
# Coefficients : [1. 2. 3.]
